# %%
from src.CartPoleEnv import CartPoleEnvCustom as CartPoleEnv
from src.agent import Agent

# %%
env = CartPoleEnv()
env.render_mode = "rgb_array"
agent = Agent(env)

# %%
rewards_per_trial = agent.learn()
# Out:
# 100%|██████████| 300/300 [01:39<00:00,  3.02it/s]

# %%
agent.plot_mean_rewards(rewards_per_trial)

# %%
agent.plot_error_bar(rewards_per_trial)

# %%
env.render_mode = "human"
print(
    "Time steps the pole was balanced for by the best parameter:", agent.run_episode()
)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 3
#       1 env.render_mode = "human"
#       2 print(
# ----> 3     "Time steps the pole was balanced for by the best parameter:", agent.run_episode()
#       4 )
#
# File ~/cart-pole/src/agent.py:55, in Agent.run_episode(self)
#      51 def run_episode(self):
#      52     """
#      53     This function is used to run an episode using the given policy.
#      54     """
# ---> 55     self.env.reset()
#      56     state = self.env.state
#      57     total_reward = 0
#
# File ~/cart-pole/src/CartPoleEnv.py:23, in CartPoleEnvCustom.reset(self, seed, options)
#      17 def reset(
#      18     self,
#      19     *,
#      20     seed: Optional[int] = None,
#      21     options: Optional[dict] = None,
#      22 ):
# ---> 23     super().reset(seed=seed)
#      24     # Note that if you use custom reset bounds, it may lead to out-of-bound
#      25     # state/observations.
#      26     low, high = 0.0, 0.0
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/classic_control/cartpole.py:209, in CartPoleEnv.reset(self, seed, options)
#     206 self.steps_beyond_terminated = None
#     208 if self.render_mode == "human":
# --> 209     self.render()
#     210 return np.array(self.state, dtype=np.float32), {}
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/classic_control/cartpole.py:299, in CartPoleEnv.render(self)
#     296 gfxdraw.hline(self.surf, 0, self.screen_width, carty, (0, 0, 0))
#     298 self.surf = pygame.transform.flip(self.surf, False, True)
# --> 299 self.screen.blit(self.surf, (0, 0))
#     300 if self.render_mode == "human":
#     301     pygame.event.pump()
#
# error: display Surface quit

# %%
env.close()
